# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as T
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
from torch.optim.lr_scheduler import CosineAnnealingLR
from sklearn.metrics import confusion_matrix
import seaborn as sns
import numpy as np

# %% [markdown]
# # Data Preparation

# %%
transform_train = T.Compose([
    T.RandomResizedCrop(32),  # Random cropping the image to 32x32 pixels
    T.RandomHorizontalFlip(),  # Flipping it horizontally
    T.ToTensor(),  # image to tensor
    T.Normalize((0.5071, 0.4867, 0.4408), (0.2675, 0.2565, 0.2761))  # Normalizing using CIFAR-100 dataset statistics
])

transform_val = T.Compose([
    T.Resize(32),  
    T.CenterCrop(32),  
    T.ToTensor(),  
    T.Normalize((0.5071, 0.4867, 0.4408), (0.2675, 0.2565, 0.2761))  # Normalizing for validation set
])

# %% [markdown]
# # Load CIFAR-100 dataset for training and validation

# %%
trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transform_train)
trainloader = DataLoader(trainset, batch_size=64, shuffle=True)  # Loading training data with batch size of 64

valset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=transform_val)
valloader = DataLoader(valset, batch_size=64, shuffle=False)  # Loading validation data

# %%
#Swish Activation Function -----
class Swish(nn.Module):  # custom module for Swish activation function
    def __init__(self):
        super(Swish, self).__init__()

    def forward(self, x):
        return x * torch.sigmoid(x)  # Swish = x * sigmoid(x)

# %% [markdown]
# # Model Defination

# %%
# Defining  the MBConvBlock for the EfficientNet model
class MBConvBlock(nn.Module):
    def __init__(self, in_channels, out_channels, expand_ratio, stride, kernel_size=3):
        super(MBConvBlock, self).__init__()
        hidden_dim = in_channels * expand_ratio  # Hidden layer size --> based on expand ratio
        self.use_res_connect = (stride == 1 and in_channels == out_channels)  # Residual connection 

        # Layers
        self.expand_conv = nn.Conv2d(in_channels, hidden_dim, 1, bias=False)  
        self.bn1 = nn.BatchNorm2d(hidden_dim)  # Batch normalization
        self.dwconv = nn.Conv2d(hidden_dim, hidden_dim, kernel_size=kernel_size, stride=stride, 
                                 padding=kernel_size // 2, groups=hidden_dim, bias=False)  #  convolution-->depthwise
        self.bn2 = nn.BatchNorm2d(hidden_dim)  # Batch normalization step
        self.se = nn.Sequential(  # Squeeze-and-excitation (SE) block
            nn.AdaptiveAvgPool2d(1),  
            nn.Conv2d(hidden_dim, hidden_dim // 4, 1),  # First 1x1 convolution
            nn.ReLU(inplace=True),
            nn.Conv2d(hidden_dim // 4, hidden_dim, 1),  # Second 1x1 convolution
            nn.Sigmoid()  # Sigmoid activation
        )
        self.pwconv = nn.Conv2d(hidden_dim, out_channels, 1, bias=False)  # Pointwise convolution
        self.bn3 = nn.BatchNorm2d(out_channels)  
        self.act = Swish()  # Swish activation

    def forward(self, x):
        out = self.act(self.bn1(self.expand_conv(x)))  # Applying the  expansion convolution + batch norm + activation
        out = self.act(self.bn2(self.dwconv(out)))  # Applying   depthwise convolution + batch norm + activation
        se_out = self.se(out)  
        out = out * se_out  
        out = self.bn3(self.pwconv(out))  # Applying pointwise convolution + batch norm
        if self.use_res_connect:
            out = x + out  # skip connction
        return out

# %%
class EfficientNetLite(nn.Module):
    def __init__(self, num_classes=100, width_coeff=1.0, depth_coeff=1.0):
        super(EfficientNetLite, self).__init__()
        base_channels = [32, 16, 24, 40, 80, 112, 192, 320, 1280]  # Base channel sizes for different stage
        scaled_channels = [int(ch * width_coeff) for ch in base_channels]  # Scaling channels based on width coefficient
        base_depths = [1, 2, 2, 3, 3, 4, 1]  # Number of MBConv blocks per stage

        # Initial stem layer: Conv2d -> BatchNorm -> Activation (Swish)
        self.stem = nn.Sequential(
            nn.Conv2d(3, scaled_channels[0], 3, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(scaled_channels[0]),
            Swish()
        )
        
        # Building MBConv blocks
        blocks = []
        blocks.append(MBConvBlock(scaled_channels[0], scaled_channels[1], expand_ratio=1, stride=1))  # First MBConv block
        blocks.append(MBConvBlock(scaled_channels[1], scaled_channels[2], expand_ratio=6, stride=2))  # Downsampling
        
        # Repeating the blocks based on depth scaling
        for _ in range(max(0, int(base_depths[1] * depth_coeff) - 1)):
            blocks.append(MBConvBlock(scaled_channels[2], scaled_channels[2], expand_ratio=6, stride=1))
        
        blocks.append(MBConvBlock(scaled_channels[2], scaled_channels[3], expand_ratio=6, stride=2))
        for _ in range(max(0, int(base_depths[2] * depth_coeff) - 1)):
            blocks.append(MBConvBlock(scaled_channels[3], scaled_channels[3], expand_ratio=6, stride=1))
        
        blocks.append(MBConvBlock(scaled_channels[3], scaled_channels[4], expand_ratio=6, stride=2))
        for _ in range(max(0, int(base_depths[3] * depth_coeff) - 1)):
            blocks.append(MBConvBlock(scaled_channels[4], scaled_channels[4], expand_ratio=6, stride=1))
        
        blocks.append(MBConvBlock(scaled_channels[4], scaled_channels[5], expand_ratio=6, stride=1))
        for _ in range(max(0, int(base_depths[4] * depth_coeff) - 1)):
            blocks.append(MBConvBlock(scaled_channels[5], scaled_channels[5], expand_ratio=6, stride=1))
        
        blocks.append(MBConvBlock(scaled_channels[5], scaled_channels[6], expand_ratio=6, stride=2))
        for _ in range(max(0, int(base_depths[5] * depth_coeff) - 1)):
            blocks.append(MBConvBlock(scaled_channels[6], scaled_channels[6], expand_ratio=6, stride=1))
        
        blocks.append(MBConvBlock(scaled_channels[6], scaled_channels[7], expand_ratio=6, stride=1))  # Final MBConv block
        
        self.blocks = nn.Sequential(*blocks)  # Wrapping all blocks in a sequential module
        
        # Head of the network
        self.head = nn.Sequential(
            nn.Conv2d(scaled_channels[7], scaled_channels[8], 1, bias=False),
            nn.BatchNorm2d(scaled_channels[8]),
            Swish()
        )
        
        # Pooling and classification layer
        self.pool = nn.AdaptiveAvgPool2d(1)  # Global average pooling
        self.dropout = nn.Dropout(0.2)  # Added dropout for regularization
        self.classifier = nn.Linear(scaled_channels[8], num_classes)  

    def forward(self, x):
        x = self.stem(x)  # Passing --> initial convolution stem
        x = self.blocks(x)  # Passing --> MBConv blocks
        x = self.head(x)  # Passing --> final convolution head
        x = self.pool(x)  # Applying global average pooling
        x = x.view(x.size(0), -1)  # Flatten the output for the classifier
        x = self.dropout(x)  # dropout
        x = self.classifier(x)  # final class predictions
        return x

# %% [markdown]
# # B0 and B1 model

# %%
model_b0 = EfficientNetLite(num_classes=100, width_coeff=1.0, depth_coeff=1.0)  # B0 model
model_b1 = EfficientNetLite(num_classes=100, width_coeff=1.2 ,depth_coeff=1.4)  # Mini B1 model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") 
model_b0 = model_b0.to(device)  # Moving B0 model to device
model_b1 = model_b1.to(device)  # Moving B1 model to device

# %% [markdown]
# # Training step

# %%
def train_model(model, trainloader, valloader, criterion, optimizer, scheduler, num_epochs=50):    #--> Training function with loss and accuracy tracking
    train_losses, val_losses = [], []
    train_accuracies, val_accuracies = [], []
    for epoch in range(num_epochs):
        model.train()  #training mode
        running_loss = 0.0
        correct, total = 0, 0
        for inputs, labels in trainloader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        scheduler.step()  # Update learning rate with scheduler
        epoch_loss = running_loss / len(trainloader)  # Average loss for the epoch
        epoch_acc = 100 * correct / total  # Accuracy for the epoch
        train_losses.append(epoch_loss)
        train_accuracies.append(epoch_acc)

        # Validation 
        model.eval()  # evaluation mode
        val_loss = 0.0
        correct, total = 0, 0
        with torch.no_grad():  # Disabling the  gradient calculation during validation---> to save memory and computation and to prevent accidental weight changes during evaluation.
            for inputs, labels in valloader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                _, predicted = torch.max(outputs, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        val_loss = val_loss / len(valloader)  # Average validation loss
        val_acc = 100 * correct / total  # Validation accuracy
        val_losses.append(val_loss)
        val_accuracies.append(val_acc)

        print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {epoch_loss:.4f}, Train Acc: {epoch_acc:.2f}%, "
              f"Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.2f}%, LR: {scheduler.get_last_lr()[0]:.6f}")
    return train_losses, train_accuracies, val_losses, val_accuracies

# %%
# Train B0-like model
print("Training B0-like Model...")
criterion = nn.CrossEntropyLoss()  # Cross-entropy loss for multi-class classification
optimizer_b0 = optim.Adam(model_b0.parameters(), lr=0.001)  # Adam optimizer with learning rate 0.001
scheduler_b0 = CosineAnnealingLR(optimizer_b0, T_max=50)  # Cosine Annealing learning rate scheduler
b0_train_losses, b0_train_accs, b0_val_losses, b0_val_accs = train_model(
    model_b0, trainloader, valloader, criterion, optimizer_b0, scheduler_b0, num_epochs=100)

# Train Mini B1-like model
print("\nTraining Mini B1 Model...")
optimizer_b1 = optim.Adam(model_b1.parameters(), lr=0.001)  # Adam optimizer for B1
scheduler_b1 = CosineAnnealingLR(optimizer_b1, T_max=50)
b1_train_losses, b1_train_accs, b1_val_losses, b1_val_accs = train_model(
    model_b1, trainloader, valloader, criterion, optimizer_b1, scheduler_b1, num_epochs=100)
# Out:
# Training B0-like Model...
# Epoch 1/100, Train Loss: 4.2235, Train Acc: 5.66%, Val Loss: 4.0319, Val Acc: 8.48%, LR: 0.000999
# Epoch 2/100, Train Loss: 3.9698, Train Acc: 7.94%, Val Loss: 3.8318, Val Acc: 9.45%, LR: 0.000996
# Epoch 3/100, Train Loss: 3.8602, Train Acc: 9.58%, Val Loss: 3.7408, Val Acc: 11.13%, LR: 0.000991
# Epoch 4/100, Train Loss: 3.8236, Train Acc: 10.27%, Val Loss: 3.8284, Val Acc: 12.12%, LR: 0.000984
# Epoch 5/100, Train Loss: 3.8942, Train Acc: 9.50%, Val Loss: 3.6978, Val Acc: 11.76%, LR: 0.000976
# Epoch 6/100, Train Loss: 3.8153, Train Acc: 10.60%, Val Loss: 3.6129, Val Acc: 13.61%, LR: 0.000965
# Epoch 7/100, Train Loss: 3.7080, Train Acc: 12.20%, Val Loss: 3.4839, Val Acc: 15.50%, LR: 0.000952
# Epoch 8/100, Train Loss: 3.7002, Train Acc: 12.66%, Val Loss: 3.5152, Val Acc: 14.67%, LR: 0.000938
# Epoch 9/100, Train Loss: 3.6624, Train Acc: 13.22%, Val Loss: 3.3942, Val Acc: 17.25%, LR: 0.000922
# Epoch 10/100, Train Loss: 3.7138, Train Acc: 12.28%, Val Loss: 3.3822, Val Acc: 17.81%, LR: 0.000905
# Epoch 11/100, Train Loss: 3.5665, Train Acc: 14.63%, Val Loss: 3.4328, Val Acc: 16.95%, LR: 0.000885
# Epoch 12/100, Train Loss: 3.4946, Train Acc: 15.83%, Val Loss: 3.2176, Val Acc: 20.62%, LR: 0.000864
# Epoch 13/100, Train Loss: 3.5928, Train Acc: 14.44%, Val Loss: 3.2652, Val Acc: 19.74%, LR: 0.000842
# Epoch 14/100, Train Loss: 3.4789, Train Acc: 16.46%, Val Loss: 3.2351, Val Acc: 20.73%, LR: 0.000819
# Epoch 15/100, Train Loss: 3.4259, Train Acc: 17.42%, Val Loss: 3.1800, Val Acc: 21.82%, LR: 0.000794
# Epoch 16/100, Train Loss: 3.4867, Train Acc: 16.50%, Val Loss: 3.4017, Val Acc: 17.64%, LR: 0.000768
# Epoch 17/100, Train Loss: 3.4446, Train Acc: 17.07%, Val Loss: 3.2120, Val Acc: 22.48%, LR: 0.000741
# Epoch 18/100, Train Loss: 3.4852, Train Acc: 16.44%, Val Loss: 3.1918, Val Acc: 21.87%, LR: 0.000713
# Epoch 19/100, Train Loss: 3.4078, Train Acc: 17.81%, Val Loss: 3.1269, Val Acc: 23.32%, LR: 0.000684
# Epoch 20/100, Train Loss: 3.3943, Train Acc: 17.93%, Val Loss: 3.2231, Val Acc: 21.14%, LR: 0.000655
# Epoch 21/100, Train Loss: 3.3266, Train Acc: 19.10%, Val Loss: 3.0664, Val Acc: 24.42%, LR: 0.000624
# Epoch 22/100, Train Loss: 3.2734, Train Acc: 20.11%, Val Loss: 3.0606, Val Acc: 24.13%, LR: 0.000594
# Epoch 23/100, Train Loss: 3.2903, Train Acc: 19.43%, Val Loss: 3.0374, Val Acc: 24.59%, LR: 0.000563
# Epoch 24/100, Train Loss: 3.2331, Train Acc: 20.74%, Val Loss: 2.9900, Val Acc: 25.44%, LR: 0.000531
# Epoch 25/100, Train Loss: 3.2058, Train Acc: 21.38%, Val Loss: 2.9771, Val Acc: 26.07%, LR: 0.000500
# Epoch 26/100, Train Loss: 3.1635, Train Acc: 22.20%, Val Loss: 2.9916, Val Acc: 26.57%, LR: 0.000469
# Epoch 27/100, Train Loss: 3.1273, Train Acc: 22.75%, Val Loss: 2.8836, Val Acc: 27.63%, LR: 0.000437
# Epoch 28/100, Train Loss: 3.0984, Train Acc: 23.36%, Val Loss: 2.8352, Val Acc: 28.31%, LR: 0.000406
# Epoch 29/100, Train Loss: 3.0704, Train Acc: 23.64%, Val Loss: 2.8640, Val Acc: 29.35%, LR: 0.000376
# Epoch 30/100, Train Loss: 3.0490, Train Acc: 24.17%, Val Loss: 2.7740, Val Acc: 29.89%, LR: 0.000345
# Epoch 31/100, Train Loss: 3.0147, Train Acc: 24.88%, Val Loss: 2.7451, Val Acc: 29.92%, LR: 0.000316
# Epoch 32/100, Train Loss: 2.9989, Train Acc: 25.24%, Val Loss: 2.8940, Val Acc: 30.02%, LR: 0.000287
# Epoch 33/100, Train Loss: 2.9778, Train Acc: 25.75%, Val Loss: 2.7310, Val Acc: 31.16%, LR: 0.000259
# Epoch 34/100, Train Loss: 2.9782, Train Acc: 25.70%, Val Loss: 2.8442, Val Acc: 30.07%, LR: 0.000232
# Epoch 35/100, Train Loss: 2.9764, Train Acc: 25.85%, Val Loss: 2.9045, Val Acc: 31.26%, LR: 0.000206
# Epoch 36/100, Train Loss: 2.9381, Train Acc: 26.50%, Val Loss: 2.8158, Val Acc: 31.46%, LR: 0.000181
# Epoch 37/100, Train Loss: 2.9152, Train Acc: 26.95%, Val Loss: 3.1478, Val Acc: 31.77%, LR: 0.000158
# Epoch 38/100, Train Loss: 2.9094, Train Acc: 27.00%, Val Loss: 2.7620, Val Acc: 32.36%, LR: 0.000136
# Epoch 39/100, Train Loss: 2.8948, Train Acc: 27.43%, Val Loss: 2.8786, Val Acc: 31.91%, LR: 0.000115
# Epoch 40/100, Train Loss: 2.8809, Train Acc: 27.66%, Val Loss: 2.8996, Val Acc: 32.69%, LR: 0.000095
# Epoch 41/100, Train Loss: 2.8736, Train Acc: 27.94%, Val Loss: 2.8872, Val Acc: 32.70%, LR: 0.000078
# Epoch 42/100, Train Loss: 2.8629, Train Acc: 27.91%, Val Loss: 3.1017, Val Acc: 32.63%, LR: 0.000062
# Epoch 43/100, Train Loss: 2.8537, Train Acc: 28.25%, Val Loss: 2.9015, Val Acc: 32.74%, LR: 0.000048
# Epoch 44/100, Train Loss: 2.8400, Train Acc: 28.32%, Val Loss: 2.8153, Val Acc: 33.04%, LR: 0.000035
# Epoch 45/100, Train Loss: 2.8430, Train Acc: 28.62%, Val Loss: 2.8879, Val Acc: 32.65%, LR: 0.000024
# Epoch 46/100, Train Loss: 2.8306, Train Acc: 28.87%, Val Loss: 2.8086, Val Acc: 32.73%, LR: 0.000016
# Epoch 47/100, Train Loss: 2.8286, Train Acc: 28.53%, Val Loss: 2.9205, Val Acc: 32.75%, LR: 0.000009
# Epoch 48/100, Train Loss: 2.8310, Train Acc: 28.71%, Val Loss: 2.7724, Val Acc: 33.37%, LR: 0.000004
# Epoch 49/100, Train Loss: 2.8245, Train Acc: 28.72%, Val Loss: 2.9206, Val Acc: 32.81%, LR: 0.000001
# Epoch 50/100, Train Loss: 2.8248, Train Acc: 28.75%, Val Loss: 3.1032, Val Acc: 32.82%, LR: 0.000000
# Epoch 51/100, Train Loss: 2.8298, Train Acc: 28.65%, Val Loss: 2.8028, Val Acc: 33.06%, LR: 0.000001
# Epoch 52/100, Train Loss: 2.8278, Train Acc: 28.64%, Val Loss: 2.9132, Val Acc: 32.87%, LR: 0.000004
# Epoch 53/100, Train Loss: 2.8218, Train Acc: 28.81%, Val Loss: 3.0208, Val Acc: 33.04%, LR: 0.000009
# Epoch 54/100, Train Loss: 2.8361, Train Acc: 28.63%, Val Loss: 2.8194, Val Acc: 33.27%, LR: 0.000016
# Epoch 55/100, Train Loss: 2.8242, Train Acc: 28.92%, Val Loss: 2.9318, Val Acc: 32.78%, LR: 0.000024
# Epoch 56/100, Train Loss: 2.8310, Train Acc: 28.72%, Val Loss: 3.0959, Val Acc: 32.60%, LR: 0.000035
# Epoch 57/100, Train Loss: 2.8271, Train Acc: 28.71%, Val Loss: 3.2638, Val Acc: 32.97%, LR: 0.000048
# Epoch 58/100, Train Loss: 2.8284, Train Acc: 28.49%, Val Loss: 3.1555, Val Acc: 32.83%, LR: 0.000062
# Epoch 59/100, Train Loss: 2.8260, Train Acc: 28.71%, Val Loss: 3.1509, Val Acc: 33.27%, LR: 0.000078
# Epoch 60/100, Train Loss: 2.8369, Train Acc: 28.57%, Val Loss: 3.1387, Val Acc: 33.13%, LR: 0.000095
# Epoch 61/100, Train Loss: 2.8236, Train Acc: 28.75%, Val Loss: 3.2014, Val Acc: 32.99%, LR: 0.000115
# Epoch 62/100, Train Loss: 2.8326, Train Acc: 28.86%, Val Loss: 2.8666, Val Acc: 33.61%, LR: 0.000136
# Epoch 63/100, Train Loss: 2.8307, Train Acc: 28.67%, Val Loss: 2.8950, Val Acc: 33.60%, LR: 0.000158
# Epoch 64/100, Train Loss: 2.8222, Train Acc: 28.69%, Val Loss: 3.0378, Val Acc: 33.28%, LR: 0.000181
# Epoch 65/100, Train Loss: 2.8304, Train Acc: 28.73%, Val Loss: 2.8094, Val Acc: 33.09%, LR: 0.000206
# Epoch 66/100, Train Loss: 2.8234, Train Acc: 28.82%, Val Loss: 2.7728, Val Acc: 32.39%, LR: 0.000232
# Epoch 67/100, Train Loss: 2.8280, Train Acc: 28.71%, Val Loss: 3.2218, Val Acc: 33.16%, LR: 0.000259
# Epoch 68/100, Train Loss: 2.8223, Train Acc: 28.75%, Val Loss: 2.6588, Val Acc: 33.88%, LR: 0.000287
# Epoch 69/100, Train Loss: 2.8427, Train Acc: 28.50%, Val Loss: 2.7754, Val Acc: 32.89%, LR: 0.000316
# Epoch 70/100, Train Loss: 2.8294, Train Acc: 28.81%, Val Loss: 2.6986, Val Acc: 33.95%, LR: 0.000345
# Epoch 71/100, Train Loss: 2.8223, Train Acc: 28.93%, Val Loss: 2.7960, Val Acc: 33.03%, LR: 0.000376
# Epoch 72/100, Train Loss: 2.8350, Train Acc: 28.46%, Val Loss: 2.6915, Val Acc: 32.90%, LR: 0.000406
# Epoch 73/100, Train Loss: 2.8193, Train Acc: 28.73%, Val Loss: 2.6941, Val Acc: 34.13%, LR: 0.000437
# Epoch 74/100, Train Loss: 2.8081, Train Acc: 29.16%, Val Loss: 2.8803, Val Acc: 33.53%, LR: 0.000469
# Epoch 75/100, Train Loss: 2.7955, Train Acc: 29.21%, Val Loss: 2.5759, Val Acc: 34.37%, LR: 0.000500
# Epoch 76/100, Train Loss: 3.0068, Train Acc: 25.45%, Val Loss: 2.7229, Val Acc: 30.84%, LR: 0.000531
# Epoch 77/100, Train Loss: 3.0089, Train Acc: 25.53%, Val Loss: 2.7681, Val Acc: 30.56%, LR: 0.000563
# Epoch 78/100, Train Loss: 3.1071, Train Acc: 23.75%, Val Loss: 2.8714, Val Acc: 27.94%, LR: 0.000594
# Epoch 79/100, Train Loss: 3.3615, Train Acc: 18.87%, Val Loss: 3.0191, Val Acc: 26.62%, LR: 0.000624
# Epoch 80/100, Train Loss: 3.2131, Train Acc: 21.27%, Val Loss: 2.9709, Val Acc: 26.43%, LR: 0.000655
# Epoch 81/100, Train Loss: 3.1866, Train Acc: 21.81%, Val Loss: 2.8403, Val Acc: 28.57%, LR: 0.000684
# Epoch 82/100, Train Loss: 3.0597, Train Acc: 24.09%, Val Loss: 2.7246, Val Acc: 30.49%, LR: 0.000713
# Epoch 83/100, Train Loss: 3.1091, Train Acc: 23.43%, Val Loss: 2.8207, Val Acc: 28.83%, LR: 0.000741
# Epoch 84/100, Train Loss: 3.0816, Train Acc: 23.91%, Val Loss: 2.8728, Val Acc: 28.13%, LR: 0.000768
# Epoch 85/100, Train Loss: 3.3599, Train Acc: 19.15%, Val Loss: 3.0679, Val Acc: 25.55%, LR: 0.000794
# Epoch 86/100, Train Loss: 3.2151, Train Acc: 21.50%, Val Loss: 3.1181, Val Acc: 25.11%, LR: 0.000819
# Epoch 87/100, Train Loss: 3.1204, Train Acc: 23.12%, Val Loss: 3.2019, Val Acc: 28.51%, LR: 0.000842
# Epoch 88/100, Train Loss: 3.0494, Train Acc: 24.60%, Val Loss: 2.7804, Val Acc: 30.97%, LR: 0.000864
# Epoch 89/100, Train Loss: 3.2117, Train Acc: 21.30%, Val Loss: 3.1455, Val Acc: 27.09%, LR: 0.000885
# Epoch 90/100, Train Loss: 3.3651, Train Acc: 18.97%, Val Loss: 3.3048, Val Acc: 21.38%, LR: 0.000905
# Epoch 91/100, Train Loss: 3.3175, Train Acc: 19.43%, Val Loss: 3.0698, Val Acc: 24.35%, LR: 0.000922
# Epoch 92/100, Train Loss: 3.2608, Train Acc: 20.39%, Val Loss: 2.9879, Val Acc: 25.75%, LR: 0.000938
# Epoch 93/100, Train Loss: 3.2014, Train Acc: 21.52%, Val Loss: 2.9534, Val Acc: 26.14%, LR: 0.000952
# Epoch 94/100, Train Loss: 3.4798, Train Acc: 16.85%, Val Loss: 3.1834, Val Acc: 23.01%, LR: 0.000965
# Epoch 95/100, Train Loss: 3.2891, Train Acc: 20.16%, Val Loss: 3.0475, Val Acc: 26.07%, LR: 0.000976
# Epoch 96/100, Train Loss: 3.3205, Train Acc: 19.60%, Val Loss: 3.0757, Val Acc: 25.56%, LR: 0.000984
# Epoch 97/100, Train Loss: 3.2423, Train Acc: 20.90%, Val Loss: 3.0467, Val Acc: 27.33%, LR: 0.000991
# Epoch 98/100, Train Loss: 3.2749, Train Acc: 20.45%, Val Loss: 3.3618, Val Acc: 21.45%, LR: 0.000996
# Epoch 99/100, Train Loss: 3.3340, Train Acc: 19.40%, Val Loss: 3.0429, Val Acc: 27.08%, LR: 0.000999
# Epoch 100/100, Train Loss: 3.3085, Train Acc: 19.61%, Val Loss: 3.2620, Val Acc: 23.46%, LR: 0.001000
#
# Training Mini B1 Model...
# Epoch 1/100, Train Loss: 4.3470, Train Acc: 4.42%, Val Loss: 4.7212, Val Acc: 4.37%, LR: 0.000999
# Epoch 2/100, Train Loss: 4.0682, Train Acc: 6.79%, Val Loss: 4.0221, Val Acc: 8.26%, LR: 0.000996
# Epoch 3/100, Train Loss: 3.9398, Train Acc: 8.43%, Val Loss: 3.9179, Val Acc: 10.10%, LR: 0.000991
# Epoch 4/100, Train Loss: 3.9121, Train Acc: 8.70%, Val Loss: 3.8703, Val Acc: 9.64%, LR: 0.000984
# Epoch 5/100, Train Loss: 3.8983, Train Acc: 9.05%, Val Loss: 3.6591, Val Acc: 12.94%, LR: 0.000976
# Epoch 6/100, Train Loss: 3.8497, Train Acc: 9.80%, Val Loss: 3.8408, Val Acc: 9.20%, LR: 0.000965
# Epoch 7/100, Train Loss: 3.9125, Train Acc: 9.16%, Val Loss: 3.8127, Val Acc: 10.46%, LR: 0.000952
# Epoch 8/100, Train Loss: 3.9310, Train Acc: 9.05%, Val Loss: 4.0359, Val Acc: 9.88%, LR: 0.000938
# Epoch 9/100, Train Loss: 3.9180, Train Acc: 9.38%, Val Loss: 3.7561, Val Acc: 10.90%, LR: 0.000922
# Epoch 10/100, Train Loss: 3.8383, Train Acc: 10.50%, Val Loss: 3.7618, Val Acc: 11.87%, LR: 0.000905
# Epoch 11/100, Train Loss: 3.8007, Train Acc: 10.76%, Val Loss: 3.5796, Val Acc: 14.60%, LR: 0.000885
# Epoch 12/100, Train Loss: 3.8292, Train Acc: 10.28%, Val Loss: 3.9426, Val Acc: 9.25%, LR: 0.000864
# Epoch 13/100, Train Loss: 3.8411, Train Acc: 10.27%, Val Loss: 3.5622, Val Acc: 14.60%, LR: 0.000842
# Epoch 14/100, Train Loss: 3.7179, Train Acc: 11.99%, Val Loss: 3.4923, Val Acc: 15.60%, LR: 0.000819
# Epoch 15/100, Train Loss: 3.7318, Train Acc: 11.83%, Val Loss: 3.6332, Val Acc: 15.06%, LR: 0.000794
# Epoch 16/100, Train Loss: 3.9527, Train Acc: 8.73%, Val Loss: 3.7953, Val Acc: 10.54%, LR: 0.000768
# Epoch 17/100, Train Loss: 3.8551, Train Acc: 9.97%, Val Loss: 3.6312, Val Acc: 13.63%, LR: 0.000741
# Epoch 18/100, Train Loss: 3.8130, Train Acc: 10.61%, Val Loss: 3.6959, Val Acc: 13.37%, LR: 0.000713
# Epoch 19/100, Train Loss: 3.8176, Train Acc: 10.96%, Val Loss: 3.5914, Val Acc: 14.03%, LR: 0.000684
# Epoch 20/100, Train Loss: 3.7516, Train Acc: 11.79%, Val Loss: 3.5320, Val Acc: 15.62%, LR: 0.000655
# Epoch 21/100, Train Loss: 3.6792, Train Acc: 12.78%, Val Loss: 3.4450, Val Acc: 16.71%, LR: 0.000624
# Epoch 22/100, Train Loss: 3.6356, Train Acc: 13.43%, Val Loss: 3.4368, Val Acc: 17.20%, LR: 0.000594
# Epoch 23/100, Train Loss: 3.6039, Train Acc: 14.20%, Val Loss: 3.4517, Val Acc: 17.29%, LR: 0.000563
# Epoch 24/100, Train Loss: 3.5797, Train Acc: 14.65%, Val Loss: 4.2549, Val Acc: 15.33%, LR: 0.000531
# Epoch 25/100, Train Loss: 3.6812, Train Acc: 13.12%, Val Loss: 3.4646, Val Acc: 17.49%, LR: 0.000500
# Epoch 26/100, Train Loss: 3.6199, Train Acc: 13.96%, Val Loss: 3.9632, Val Acc: 16.91%, LR: 0.000469
# Epoch 27/100, Train Loss: 3.6200, Train Acc: 13.90%, Val Loss: 3.4115, Val Acc: 18.11%, LR: 0.000437
# Epoch 28/100, Train Loss: 3.5464, Train Acc: 15.00%, Val Loss: 3.3231, Val Acc: 18.62%, LR: 0.000406
# Epoch 29/100, Train Loss: 3.5045, Train Acc: 15.84%, Val Loss: 3.2652, Val Acc: 19.72%, LR: 0.000376
# Epoch 30/100, Train Loss: 3.5261, Train Acc: 15.69%, Val Loss: 3.4401, Val Acc: 17.07%, LR: 0.000345
# Epoch 31/100, Train Loss: 3.5430, Train Acc: 15.28%, Val Loss: 3.3862, Val Acc: 19.83%, LR: 0.000316
# Epoch 32/100, Train Loss: 3.4761, Train Acc: 16.32%, Val Loss: 3.2861, Val Acc: 20.47%, LR: 0.000287
# Epoch 33/100, Train Loss: 3.4767, Train Acc: 16.36%, Val Loss: 3.2521, Val Acc: 20.90%, LR: 0.000259
# Epoch 34/100, Train Loss: 3.4773, Train Acc: 16.60%, Val Loss: 3.2828, Val Acc: 20.15%, LR: 0.000232
# Epoch 35/100, Train Loss: 3.4307, Train Acc: 17.08%, Val Loss: 3.2145, Val Acc: 21.06%, LR: 0.000206
# Epoch 36/100, Train Loss: 3.4562, Train Acc: 16.92%, Val Loss: 3.2160, Val Acc: 20.77%, LR: 0.000181
# Epoch 37/100, Train Loss: 3.4131, Train Acc: 17.59%, Val Loss: 3.1852, Val Acc: 21.34%, LR: 0.000158
# Epoch 38/100, Train Loss: 3.3925, Train Acc: 18.07%, Val Loss: 3.1667, Val Acc: 22.01%, LR: 0.000136
# Epoch 39/100, Train Loss: 3.3862, Train Acc: 18.20%, Val Loss: 3.1580, Val Acc: 21.93%, LR: 0.000115
# Epoch 40/100, Train Loss: 3.3828, Train Acc: 18.14%, Val Loss: 3.1420, Val Acc: 22.63%, LR: 0.000095
# Epoch 41/100, Train Loss: 3.3550, Train Acc: 18.54%, Val Loss: 3.1400, Val Acc: 22.67%, LR: 0.000078
# Epoch 42/100, Train Loss: 3.3487, Train Acc: 18.81%, Val Loss: 3.1375, Val Acc: 22.63%, LR: 0.000062
# Epoch 43/100, Train Loss: 3.3346, Train Acc: 19.35%, Val Loss: 3.1165, Val Acc: 23.01%, LR: 0.000048
# Epoch 44/100, Train Loss: 3.3244, Train Acc: 19.27%, Val Loss: 3.1188, Val Acc: 23.05%, LR: 0.000035
# Epoch 45/100, Train Loss: 3.3150, Train Acc: 19.48%, Val Loss: 3.1151, Val Acc: 22.97%, LR: 0.000024
# Epoch 46/100, Train Loss: 3.3100, Train Acc: 19.50%, Val Loss: 3.1431, Val Acc: 23.18%, LR: 0.000016
# Epoch 47/100, Train Loss: 3.3012, Train Acc: 19.64%, Val Loss: 3.1287, Val Acc: 22.92%, LR: 0.000009
# Epoch 48/100, Train Loss: 3.3078, Train Acc: 19.71%, Val Loss: 3.1571, Val Acc: 22.60%, LR: 0.000004
# Epoch 49/100, Train Loss: 3.3104, Train Acc: 19.71%, Val Loss: 3.1009, Val Acc: 23.36%, LR: 0.000001
# Epoch 50/100, Train Loss: 3.3071, Train Acc: 19.72%, Val Loss: 3.1107, Val Acc: 23.10%, LR: 0.000000
# Epoch 51/100, Train Loss: 3.3126, Train Acc: 19.72%, Val Loss: 3.1045, Val Acc: 23.34%, LR: 0.000001
# Epoch 52/100, Train Loss: 3.3067, Train Acc: 19.51%, Val Loss: 3.1023, Val Acc: 23.31%, LR: 0.000004
# Epoch 53/100, Train Loss: 3.3122, Train Acc: 19.65%, Val Loss: 3.1126, Val Acc: 23.67%, LR: 0.000009
# Epoch 54/100, Train Loss: 3.3008, Train Acc: 19.73%, Val Loss: 3.1017, Val Acc: 23.32%, LR: 0.000016
# Epoch 55/100, Train Loss: 3.3005, Train Acc: 19.71%, Val Loss: 3.0836, Val Acc: 23.67%, LR: 0.000024
# Epoch 56/100, Train Loss: 3.3035, Train Acc: 19.93%, Val Loss: 3.1010, Val Acc: 23.78%, LR: 0.000035
# Epoch 57/100, Train Loss: 3.3001, Train Acc: 20.03%, Val Loss: 3.0933, Val Acc: 23.66%, LR: 0.000048
# Epoch 58/100, Train Loss: 3.3036, Train Acc: 19.90%, Val Loss: 3.0933, Val Acc: 23.57%, LR: 0.000062
# Epoch 59/100, Train Loss: 3.3011, Train Acc: 19.88%, Val Loss: 3.0999, Val Acc: 23.38%, LR: 0.000078
# Epoch 60/100, Train Loss: 3.2967, Train Acc: 19.84%, Val Loss: 3.1276, Val Acc: 23.49%, LR: 0.000095
# Epoch 61/100, Train Loss: 3.3038, Train Acc: 19.82%, Val Loss: 3.0778, Val Acc: 23.80%, LR: 0.000115
# Epoch 62/100, Train Loss: 3.2925, Train Acc: 20.01%, Val Loss: 3.0903, Val Acc: 23.96%, LR: 0.000136
# Epoch 63/100, Train Loss: 3.2931, Train Acc: 19.93%, Val Loss: 3.0882, Val Acc: 23.74%, LR: 0.000158
# Epoch 64/100, Train Loss: 3.3035, Train Acc: 20.01%, Val Loss: 3.0777, Val Acc: 23.77%, LR: 0.000181
# Epoch 65/100, Train Loss: 3.3330, Train Acc: 19.27%, Val Loss: 3.1392, Val Acc: 23.25%, LR: 0.000206
# Epoch 66/100, Train Loss: 3.3139, Train Acc: 19.63%, Val Loss: 3.1120, Val Acc: 24.12%, LR: 0.000232
# Epoch 67/100, Train Loss: 3.3274, Train Acc: 19.35%, Val Loss: 3.0841, Val Acc: 23.95%, LR: 0.000259
# Epoch 68/100, Train Loss: 3.3047, Train Acc: 19.95%, Val Loss: 3.1333, Val Acc: 23.23%, LR: 0.000287
# Epoch 69/100, Train Loss: 3.3379, Train Acc: 19.20%, Val Loss: 3.1101, Val Acc: 23.38%, LR: 0.000316
# Epoch 70/100, Train Loss: 3.3131, Train Acc: 19.63%, Val Loss: 3.2014, Val Acc: 23.32%, LR: 0.000345
# Epoch 71/100, Train Loss: 3.3005, Train Acc: 19.70%, Val Loss: 3.1024, Val Acc: 23.58%, LR: 0.000376
# Epoch 72/100, Train Loss: 3.3519, Train Acc: 19.02%, Val Loss: 3.2310, Val Acc: 21.93%, LR: 0.000406
# Epoch 73/100, Train Loss: 3.3926, Train Acc: 18.41%, Val Loss: 3.1327, Val Acc: 22.79%, LR: 0.000437
# Epoch 74/100, Train Loss: 3.3189, Train Acc: 19.40%, Val Loss: 3.1233, Val Acc: 24.14%, LR: 0.000469
# Epoch 75/100, Train Loss: 3.3202, Train Acc: 19.59%, Val Loss: 3.1397, Val Acc: 22.62%, LR: 0.000500
# Epoch 76/100, Train Loss: 3.3422, Train Acc: 18.97%, Val Loss: 3.1049, Val Acc: 23.85%, LR: 0.000531
# Epoch 77/100, Train Loss: 3.4398, Train Acc: 17.72%, Val Loss: 3.2938, Val Acc: 19.90%, LR: 0.000563
# Epoch 78/100, Train Loss: 3.5503, Train Acc: 15.68%, Val Loss: 3.5030, Val Acc: 15.63%, LR: 0.000594
# Epoch 79/100, Train Loss: 3.4596, Train Acc: 16.98%, Val Loss: 3.1213, Val Acc: 22.71%, LR: 0.000624
# Epoch 80/100, Train Loss: 3.3343, Train Acc: 19.00%, Val Loss: 3.1024, Val Acc: 22.84%, LR: 0.000655
# Epoch 81/100, Train Loss: 3.4191, Train Acc: 17.82%, Val Loss: 3.1096, Val Acc: 23.65%, LR: 0.000684
# Epoch 82/100, Train Loss: 3.3452, Train Acc: 19.13%, Val Loss: 3.9027, Val Acc: 21.65%, LR: 0.000713
# Epoch 83/100, Train Loss: 3.2948, Train Acc: 19.69%, Val Loss: 3.0979, Val Acc: 24.06%, LR: 0.000741
# Epoch 84/100, Train Loss: 3.4229, Train Acc: 17.43%, Val Loss: 3.2260, Val Acc: 21.47%, LR: 0.000768
# Epoch 85/100, Train Loss: 3.3237, Train Acc: 19.34%, Val Loss: 3.0670, Val Acc: 24.01%, LR: 0.000794
# Epoch 86/100, Train Loss: 3.2920, Train Acc: 19.76%, Val Loss: 3.1154, Val Acc: 23.89%, LR: 0.000819
# Epoch 87/100, Train Loss: 3.3550, Train Acc: 18.93%, Val Loss: 3.3022, Val Acc: 21.97%, LR: 0.000842
# Epoch 88/100, Train Loss: 3.4672, Train Acc: 16.98%, Val Loss: 3.2786, Val Acc: 20.98%, LR: 0.000864
# Epoch 89/100, Train Loss: 3.3712, Train Acc: 18.41%, Val Loss: 3.0606, Val Acc: 23.48%, LR: 0.000885
# Epoch 90/100, Train Loss: 3.3595, Train Acc: 18.98%, Val Loss: 3.1686, Val Acc: 22.57%, LR: 0.000905
# Epoch 91/100, Train Loss: 3.4575, Train Acc: 17.09%, Val Loss: 3.5933, Val Acc: 17.03%, LR: 0.000922
# Epoch 92/100, Train Loss: 3.4460, Train Acc: 17.27%, Val Loss: 3.1721, Val Acc: 22.83%, LR: 0.000938
# Epoch 93/100, Train Loss: 3.3223, Train Acc: 19.42%, Val Loss: 3.0243, Val Acc: 25.10%, LR: 0.000952
# Epoch 94/100, Train Loss: 3.3175, Train Acc: 19.44%, Val Loss: 3.0080, Val Acc: 25.28%, LR: 0.000965
# Epoch 95/100, Train Loss: 3.2745, Train Acc: 20.25%, Val Loss: 3.0032, Val Acc: 25.81%, LR: 0.000976
# Epoch 96/100, Train Loss: 3.2895, Train Acc: 20.24%, Val Loss: 2.9893, Val Acc: 26.24%, LR: 0.000984
# Epoch 97/100, Train Loss: 3.2811, Train Acc: 20.14%, Val Loss: 3.0717, Val Acc: 24.08%, LR: 0.000991
# Epoch 98/100, Train Loss: 3.2301, Train Acc: 21.21%, Val Loss: 2.9751, Val Acc: 25.93%, LR: 0.000996
# Epoch 99/100, Train Loss: 3.2697, Train Acc: 20.59%, Val Loss: 3.0686, Val Acc: 23.94%, LR: 0.000999
# Epoch 100/100, Train Loss: 3.1717, Train Acc: 21.92%, Val Loss: 2.9782, Val Acc: 27.53%, LR: 0.001000

# %% [markdown]
# # graph plot

# %%
plt.figure(figsize=(14, 5))  # Plotting the evaluation metrics for both models
# Accuracy comparison plot
plt.subplot(1, 2, 1)
plt.plot(b0_val_accs, label='B0 Validation Accuracy')
plt.plot(b1_val_accs, label='B1 Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Validation Top-1 Accuracy vs. Epochs')
plt.legend()

# Loss comparison plot
plt.subplot(1, 2, 2)
plt.plot(b0_val_losses, label='B0 Validation Loss')
plt.plot(b1_val_losses, label='B1 Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Validation Loss vs. Epochs')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Discussion

# %% [markdown]
# # EfficientNet Training Results
#
# ## B0 Model:
# - **Final Validation Top-1 Accuracy**: 23.46% (Epoch 100)
# - **Final Validation Loss**: 3.2620
# - **Training Accuracy (Epoch 100)**: 19.61%
# - **Peak Validation Accuracy**: 34.37% (Epoch 75)
#
# ### Observations:
# - B0 starts with a validation accuracy of **8.48% at Epoch 1** and improves steadily, peaking at **34.37% by Epoch 75**.
# - After Epoch 75, there’s a noticeable decline in validation accuracy, dropping to **23.46% by Epoch 100**, while training accuracy remains relatively stable (**around 28-29% until Epoch 75, then dropping to 19.61%**).
# - Validation loss decreases initially (**from 4.0319 to 2.5759 by Epoch 75**) but shows significant fluctuations and an **upward trend after Epoch 75**, reaching **3.2620 by the end**.
#
# ---
#
# ## B1 Model:
# - **Final Validation Top-1 Accuracy**: 27.53% (Epoch 100)
# - **Final Validation Loss**: 2.9782
# - **Training Accuracy (Epoch 100)**: 21.92%
# - **Peak Validation Accuracy**: 27.53% (Epoch 100)
#
# ### Observations:
# - B1 starts with a lower validation accuracy of **4.37% at Epoch 1** but shows a **more consistent upward trend**, reaching **27.53% by Epoch 100**.
# - Training accuracy improves steadily from **4.42% to 21.92% over 100 epochs**, with **fewer drastic drops compared to B0**.
# - Validation loss decreases from **4.7212 to 2.9782**, with fluctuations but a **more stable trend compared to B0, especially after Epoch 50**.

# %% [markdown]
# ## 2. Comparison of B0 vs. B1
#
# ### Accuracy:
# #### Early Training (Epochs 1-50):
# - **B0 outperforms B1 significantly** in the first 50 epochs.
# - At **Epoch 50**, B0 achieves a **validation accuracy of 32.82%**, while B1 is at **23.10%**.
# - This suggests **B0 learns faster initially**, likely due to its **simpler architecture** (`width_coeff=1.0`, `depth_coeff=1.0`), which may **converge more quickly on a smaller parameter space**.
#
# #### Later Training (Epochs 51-100):
# - **B1 catches up and surpasses B0 after Epoch 50**.
# - By **Epoch 100**, B1’s validation accuracy is **27.53%**, compared to B0’s **23.46%**.
# - B1’s **higher capacity** (`width_coeff=1.2`, `depth_coeff=1.4`) and **dropout (0.2)** likely help it **generalize better in the later stages**, avoiding the sharp decline seen in B0.
#
# #### Peak Performance:
# - **B0 peaks at 34.37% (Epoch 75)**, higher than **B1’s peak of 27.53% (Epoch 100)**.
# - However, **B0’s peak is not sustained**, indicating **potential overfitting**, while **B1’s performance is more stable and ends higher**.
#
# ---
#
# ### Loss:
# #### B0 Validation Loss:
# - **Shows high volatility**, especially after Epoch 50, with **spikes** (e.g., `3.3618` at Epoch 98) and a **final value of 3.2620**.
# - The **initial decrease** (to `2.5759` by Epoch 75) followed by an **increase** suggests **overfitting**, as the model **fails to generalize well after a certain point**.
#
# #### B1 Validation Loss:
# - **Also fluctuates** but **trends downward more consistently**, ending at `2.9782`.
# - While there are **spikes** (e.g., `4.2549` at Epoch 24), **B1’s loss stabilizes better than B0’s**, indicating **improved generalization**.

# %% [markdown]
# # Bonus

# %% [markdown]
# ### Question 1

# %% [markdown]
# ### 1.1 What is the advantage of using `nn.Embedding` over manually creating one-hot vectors for each token? In what scenarios might manual one-hot encoding still be viable?
#
# Using `nn.Embedding` is much more efficient compared to manually creating one-hot vectors. One-hot encoding creates very sparse vectors with only one '1' in a sea of '0's, which can lead to a lot of memory usage, especially for large vocabularies. With `nn.Embedding`, each token is mapped to a dense, learnable vector, which allows the model to better capture relationships between words and is much more memory-efficient.
# However, in small problems with very limited vocabulary and when the overhead of learning embeddings isn’t justified, manual one-hot encoding might still be acceptable for simplicity.

# %% [markdown]
# ### 1.2 What is `self.dropout()`? When and where can we use dropout?
#
# `self.dropout()` is a regularization technique used to prevent overfitting by randomly setting some of the input elements to zero during training. It forces the model to not rely too heavily on any one feature, improving generalization. Dropout can be used after any layer where overfitting might be a concern, like after the embedding layer or even before the output layer in deep models. It’s especially useful when training models on small datasets or very complex models.

# %% [markdown]
# ## Question 2

# %% [markdown]
# ### 2.1 How exactly does PyTorch handle backpropagation through all these timesteps?
#
# PyTorch handles backpropagation through the timesteps in a way that makes it efficient for sequence models. For each timestep in a sequence, the model calculates the gradients and stores them in a computational graph. During the backward pass, PyTorch will automatically apply backpropagation through each timestep in reverse order. This means it updates the parameters (weights) based on the error at each step, making it easier to train models like RNNs that work with sequences.

# %% [markdown]
# ## Question 3

# %% [markdown]
# ### 3.1 Why do we use `nn.LogSoftmax(dim=1)` instead of `nn.Softmax`? How does this choice affect the loss function that we use during training?
#
# We use `nn.LogSoftmax` instead of `nn.Softmax` because it’s more numerically stable when combined with `nn.NLLLoss` (negative log-likelihood loss). Softmax outputs probabilities, but applying the log to these probabilities before passing them into the loss function avoids issues with very small numbers, making training more stable. The log conversion also directly aligns with how `nn.NLLLoss` expects the input, which improves the efficiency and performance of the model during training
